# %% [markdown]
# <h1> Комментарий тимлида </h1>
#
# 👋 **Привет, Ольга!**
#
# ✨ Поздравляю с началом работы над финальным проектом!
#
# Меня зовут Арсен Абдулин и я буду твоим ревьювером. Предлагаю общаться на «ты», если не против =)
#
# При проверке работ я делаю следующие комментарии:
#
# <div class="alert alert-success">
# <b>✔️ Зеленым цветом</b> отмечены удачные решения.</div>
#
# <div class="alert alert-warning">
# <b>⚠️ Желтым цветом</b> я отметил пункты, которые в следующий раз можно сделать по-другому. Одно-два таких замечания в проекте допускается, но если их много — проект следует доработать. </div>
#
# <div class="alert alert-danger">
# <b>🚫 Красным цветом</b> отмечены критические замечания, которые необходимо поправить, чтобы принять проект. </div>
#
# Если какие-то моменты в задании для тебя были непонятны и у тебя есть ко мне вопросы — смело спрашивай 😊 Также ты можешь доработать места, где есть желтые комментарии в проекте (однако, это не обязательно).
#
# Предлагаю работать в диалоге: если ты решишь что-то поменять по моим рекомендациям — пиши об этом (выбери для своих комментариев определенный цвет - так мне будет легче увидеть изменения). Пожалуйста не перемещай, не изменяй и не удаляй мои комментарии. Все это поможет сделать проверку твоего проекта оперативнее.
#
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Пример комментария. </div>

# %% [markdown]
# **План работы:**
# 1. Открытие данных, краткое описание. Здесь мы знакомимся с датасетами и признаками, производим начальный анализ (смотрим объём данных и пропуски, конвертируем столбцы даты в нужный формат, уникальные идентификаторы клиентов - в индексы).
# 2. Исследовательский анализ данных. Детально изучаем данные, получаем целевой признак, объединяем датасеты. Также изучаем признаки на предмет мультиколлинеарности, создаём новые, которых нет в исходных данных, но они понадобятся для обучения.
# 3. Создаём выборки, масштабируем численные признаки и кодируем категориальные в ОНЕ. Создаём модели, обучаем их и подбираем лучшую с помощью кросс-валидации.
# 4. Найденную лучшую модель проверяем на тестовой выборке, строим её ROC-кривую. Выводим финальный результат.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span><ul class="toc-item"><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Описание-признаков" data-toc-modified-id="Описание-признаков-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Описание признаков</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Импорт-библиотек,-знакомство-с-данными" data-toc-modified-id="Импорт-библиотек,-знакомство-с-данными-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Импорт библиотек, знакомство с данными</a></span></li><li><span><a href="#Исследование-и-начальная-обработка-данных" data-toc-modified-id="Исследование-и-начальная-обработка-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Исследование и начальная обработка данных</a></span></li><li><span><a href="#Объединение-датасетов,-избавление-от-ненужных-признаков" data-toc-modified-id="Объединение-датасетов,-избавление-от-ненужных-признаков-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Объединение датасетов, избавление от ненужных признаков</a></span></li><li><span><a href="#Анализ-категорий-клиентов:-ушедшие-и-действующие,-использование-услуг" data-toc-modified-id="Анализ-категорий-клиентов:-ушедшие-и-действующие,-использование-услуг-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Анализ категорий клиентов: ушедшие и действующие, использование услуг</a></span></li></ul></li><li><span><a href="#Создание-выборок,-обучение-моделей" data-toc-modified-id="Создание-выборок,-обучение-моделей-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Создание выборок, обучение моделей</a></span><ul class="toc-item"><li><span><a href="#Разбиение-на-выборки,-ОНЕ" data-toc-modified-id="Разбиение-на-выборки,-ОНЕ-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Разбиение на выборки, ОНЕ</a></span></li><li><span><a href="#Создание-и-обучение-моделей" data-toc-modified-id="Создание-и-обучение-моделей-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Создание и обучение моделей</a></span></li></ul></li><li><span><a href="#Тестирование-финальной-модели,-выводы" data-toc-modified-id="Тестирование-финальной-модели,-выводы-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование финальной модели, выводы</a></span><ul class="toc-item"><li><span><a href="#Проверка-модели-на-тестовой-выборке" data-toc-modified-id="Проверка-модели-на-тестовой-выборке-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Проверка модели на тестовой выборке</a></span></li><li><span><a href="#ROC-кривая" data-toc-modified-id="ROC-кривая-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>ROC-кривая</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Уточняющие-вопросы" data-toc-modified-id="Уточняющие-вопросы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Уточняющие вопросы</a></span></li><li><span><a href="#Цель-проекта" data-toc-modified-id="Цель-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Цель проекта</a></span></li></ul></div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> Хорошо, когда есть подробное описание проекта — так построннему человеку будет проще ознакомиться!
#
# </div>

# %% [markdown]
# # Финальный спринт: домен Телеком
# # «Прогнозирование оттока клиентов»
# ## Описание проекта
# Оператор связи «Ниединогоразрыва.ком» хочет научиться прогнозировать отток клиентов. Если выяснится, что пользователь планирует уйти, ему будут предложены промокоды и специальные условия. Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и договорах.
#
# ### Описание данных
# Данные состоят из файлов, полученных из разных источников:
# * `contract_new.csv` — информация о договоре;
# * `personal_new.csv` — персональные данные клиента;
# * `internet_new.csv` — информация об интернет-услугах;
# * `phone_new.csv` — информация об услугах телефонии.
#
# ### Описание признаков
# * `BeginDate` – дата начала пользования услугами,
# * `EndDate` – дата окончания пользования услугами (если она No - клиент не ушёл),
# * `Type` – тип оплаты: ежемесячный, годовой и тд,
# * `PaperlessBilling` – безналичный расчет,
# * `PaymentMethod` – способ оплаты,
# * `MonthlyCharges` – ежемесячные траты на услуги,
# * `TotalCharges` – всего потрачено денег на услуги
# * `Dependents` – наличие иждивенцев
# * `Senior Citizen` – наличие пенсионного статуса по возрасту
# * `Partner` – наличие супруга(и)
# * `MultipleLines` – наличие возможности ведения параллельных линий во время
# звонка
#
# ## Исследовательский анализ данных
# ### Импорт библиотек, знакомство с данными

# %%
# !pip install -q phik
# !pip install -U -q scikit-learn
# !pip install -U -q matplotlib
# !pip install -U -q seaborn
# !pip install catboost

# %%
# импорты
import warnings
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import phik
from phik.report import plot_correlation_matrix
from phik import report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoost, CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.utils import shuffle
from sklearn.model_selection import (
    GridSearchCV,
    RandomizedSearchCV,
    train_test_split,
    cross_val_score
)
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import (
    OneHotEncoder,
    StandardScaler
)

from sklearn.metrics import (
    f1_score,
    accuracy_score,
    roc_auc_score,
    roc_curve,
    precision_score,
    confusion_matrix,
    auc
)

#настройки
warnings.filterwarnings("ignore")


# константы
RANDOM_STATE = 140823 # дата понедельника начала финального спринта
TEST_SIZE = 0.25 # размер тестовой выборки

# %%
try:
    data_contract = pd.read_csv('contract_new.csv', index_col=['customerID'], parse_dates=['BeginDate', 'EndDate'])
    data_personal = pd.read_csv('personal_new.csv', index_col='customerID')
    data_internet = pd.read_csv('internet_new.csv', index_col='customerID')
    data_phone = pd.read_csv('phone_new.csv', index_col='customerID')
except:
    data_contract = pd.read_csv('/datasets/contract_new.csv', index_col='customerID')
    data_personal = pd.read_csv('/datasets/personal_new.csv', index_col='customerID')
    data_internet = pd.read_csv('/datasets/internet_new.csv', index_col='customerID')
    data_phone = pd.read_csv('/datasets/phone_new.csv', index_col='customerID')

# %% [markdown]
# Столбец `customerID` содержит уникальный идентификатор пользователя, по которому можно объединять данные при необходимости. Поэтому можно сделать его индексом таблиц.

# %%
data = [data_contract, data_personal, data_internet, data_phone]

for d in data:
    display(d.head())
    display(d.info())
# Out:
#             BeginDate EndDate            Type PaperlessBilling  \
# customerID
# 7590-VHVEG 2020-01-01      No  Month-to-month              Yes
# 5575-GNVDE 2017-04-01      No        One year               No
# 3668-QPYBK 2019-10-01      No  Month-to-month              Yes
# 7795-CFOCW 2016-05-01      No        One year               No
# 9237-HQITU 2019-09-01      No  Month-to-month              Yes
#
#                         PaymentMethod  MonthlyCharges TotalCharges
# customerID
# 7590-VHVEG           Electronic check           29.85        31.04
# 5575-GNVDE               Mailed check           56.95      2071.84
# 3668-QPYBK               Mailed check           53.85       226.17
# 7795-CFOCW  Bank transfer (automatic)           42.30       1960.6
# 9237-HQITU           Electronic check           70.70        353.5
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 7 columns):
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> Правильное замечание, пропуски действительно нужно будет обработать
#
# </div>

# %% [markdown]
# Пропусков в датасетах нет, но не во всех есть данные обо всех существующих пользователях (если датасеты объединять, пропуски появятся).
# ### Исследование и начальная обработка данных

# %%
print('Начало датасета:', min(data_contract['BeginDate']))
print('Конец датасета:', max(data_contract['BeginDate']))
print('Конечные даты:', data_contract['EndDate'].value_counts())
# Out:
# Начало датасета: 2013-10-01 00:00:00
# Конец датасета: 2020-02-01 00:00:00
# Конечные даты: No            5942
# 2020-01-01      39
# 2019-12-01      38
# 2018-11-01      35
# 2019-09-01      32
#               ...
# 2015-04-01       2
# 2014-12-01       2
# 2014-10-01       1
# 2014-11-01       1
# 2014-06-01       1
# Name: EndDate, Length: 67, dtype: int64

# %% [markdown]
# Датасет охватывает 7 лет с 2013 по 2020 годы. Пользователи подключаются/отключаются 1 числа месяца. Под целевой признак (ушёл или нет клиент) нужно создать отдельный столбец, где значение No из столбца EndDate станет 0 (клиент не ушёл), а любая дата - 1 (клиент ушёл), поскольку предсказывать нам нужно именно факт ухода, а не дату.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> Отлично, получили целевую переменную!
#
# </div>

# %%
data_contract['ClientLeft'] = (data_contract['EndDate'] != 'No').astype(int)
data_contract.head()
# Out:
#             BeginDate EndDate            Type PaperlessBilling  \
# customerID
# 7590-VHVEG 2020-01-01      No  Month-to-month              Yes
# 5575-GNVDE 2017-04-01      No        One year               No
# 3668-QPYBK 2019-10-01      No  Month-to-month              Yes
# 7795-CFOCW 2016-05-01      No        One year               No
# 9237-HQITU 2019-09-01      No  Month-to-month              Yes
#
#                         PaymentMethod  MonthlyCharges TotalCharges  ClientLeft
# customerID
# 7590-VHVEG           Electronic check           29.85        31.04           0
# 5575-GNVDE               Mailed check           56.95      2071.84           0
# 3668-QPYBK               Mailed check           53.85       226.17           0
# 7795-CFOCW  Bank transfer (automatic)           42.30       1960.6           0
# 9237-HQITU           Electronic check           70.70        353.5           0

# %% [markdown]
# Почему-то в TotalCharges тип данных - object, а не численный.

# %%
data_contract['TotalCharges'].value_counts()
# Out:
#            11
# 20.45       6
# 101.0       5
# 21.53       4
# 19.65       4
#            ..
# 1002.13     1
# 5203.2      1
# 223.42      1
# 44.39       1
# 385.84      1
# Name: TotalCharges, Length: 6658, dtype: int64

# %% [markdown]
# Есть строки, заполненные пробелами. Преобразуем в численный тип, а ошибки (пробелы) преобразуются в NaN:

# %%
data_contract['TotalCharges'] = pd.to_numeric(data_contract['TotalCharges'], errors='coerce')
data_contract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BeginDate         7043 non-null   datetime64[ns]
#  1   EndDate           7043 non-null   object
#  2   Type              7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7032 non-null   float64
#  7   ClientLeft        7043 non-null   int32
# dtypes: datetime64[ns](1), float64(2), int32(1), object(4)
# memory usage: 467.7+ KB

# %% [markdown]
# Это даст 11 пропусков. Изучим строки с ними:

# %%
data_contract[data_contract['TotalCharges'].isnull()]
# Out:
#             BeginDate EndDate      Type PaperlessBilling  \
# customerID
# 4472-LVYGI 2020-02-01      No  Two year              Yes
# 3115-CZMZD 2020-02-01      No  Two year               No
# 5709-LVOEQ 2020-02-01      No  Two year               No
# 4367-NUYAO 2020-02-01      No  Two year               No
# 1371-DWPAZ 2020-02-01      No  Two year               No
# 7644-OMVMY 2020-02-01      No  Two year               No
# 3213-VVOLG 2020-02-01      No  Two year               No
# 2520-SGTTA 2020-02-01      No  Two year               No
# 2923-ARZLG 2020-02-01      No  One year              Yes
# 4075-WKNIU 2020-02-01      No  Two year               No
# 2775-SEFEE 2020-02-01      No  Two year              Yes
#
#                         PaymentMethod  MonthlyCharges  TotalCharges  \
# customerID
# 4472-LVYGI  Bank transfer (automatic)           52.55           NaN
# 3115-CZMZD               Mailed check           20.25           NaN
# ...

# %% [markdown]
# Все эти клиенты подключены в последний день, охваченный датасетом - BeginDate составляет 2020-02-01, максимальное число в этом столбце. Заплатить что-либо они просто не успели.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> Хорошо, что обратила внимание на пустые строки в признаке TotalCharges!
#
# Как вариант, такие пропуски можно заполнить месячными значениями платежей
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Я как-то об этом не подумала. Переписала заполнение.</div>

# %%
data_contract['TotalCharges'] = data_contract['TotalCharges'].fillna(data_contract['MonthlyCharges'])
data_contract.loc[['4472-LVYGI']] # смотрим, заполнилось ли, по одному из ID с прошлого вывода
# Out:
#             BeginDate EndDate      Type PaperlessBilling  \
# customerID
# 4472-LVYGI 2020-02-01      No  Two year              Yes
#
#                         PaymentMethod  MonthlyCharges  TotalCharges  \
# customerID
# 4472-LVYGI  Bank transfer (automatic)           52.55         52.55
#
#             ClientLeft
# customerID
# 4472-LVYGI           0

# %% [markdown]
# Также создаём новый признак - длительность пребывания клиента у провайдера в днях, для чего вычитаем BeginDate из EndDate. Но значения No нужно заменить на дату формирования датасета; тут я создаю вспомогательный столбец EndDateFilled, чтобы не помешало преобразованию No в целевой признак (если вдруг понадобится перезапустить какие-то ячейки кода).

# %%
data_contract['EndDateFilled'] = data_contract['EndDate'].where(data_contract['EndDate'] != 'No', '2020-02-01')
data_contract['EndDateFilled'] = pd.to_datetime(data_contract['EndDateFilled'])

# %% [markdown]
# Теперь создаём признак длительности.

# %%
data_contract['Duration'] = (data_contract['EndDateFilled'] - data_contract['BeginDate']).dt.days
data_contract.head()
# Out:
#             BeginDate EndDate            Type PaperlessBilling  \
# customerID
# 7590-VHVEG 2020-01-01      No  Month-to-month              Yes
# 5575-GNVDE 2017-04-01      No        One year               No
# 3668-QPYBK 2019-10-01      No  Month-to-month              Yes
# 7795-CFOCW 2016-05-01      No        One year               No
# 9237-HQITU 2019-09-01      No  Month-to-month              Yes
#
#                         PaymentMethod  MonthlyCharges  TotalCharges  \
# customerID
# 7590-VHVEG           Electronic check           29.85         31.04
# 5575-GNVDE               Mailed check           56.95       2071.84
# 3668-QPYBK               Mailed check           53.85        226.17
# 7795-CFOCW  Bank transfer (automatic)           42.30       1960.60
# 9237-HQITU           Electronic check           70.70        353.50
#
#             ClientLeft EndDateFilled  Duration
# customerID
# 7590-VHVEG           0    2020-02-01        31
# ...

# %% [markdown]
# Переименовываем в data_personal столбец gender в Gender для единообразия.

# %%
data_personal = data_personal.rename(columns={"gender": "Gender"})
data_personal.head()
# Out:
#             Gender  SeniorCitizen Partner Dependents
# customerID
# 7590-VHVEG  Female              0     Yes         No
# 5575-GNVDE    Male              0      No         No
# 3668-QPYBK    Male              0      No         No
# 7795-CFOCW    Male              0      No         No
# 9237-HQITU  Female              0      No         No

# %% [markdown]
# В датасетах по интернету и телефонии создаём признаки, которые позволят их категоризировать в объединённом:

# %%
data_internet['Internet'] = 1
data_phone['Phone'] = 1

# %%
def histogram(data, title, xlabel, ylabel, bins=len(data)+1):
    plt.hist(data, bins=bins)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    
histogram(data_contract['ClientLeft'], 'Уход клиента', 'Клиент не ушёл/ушёл', 'Количество клиентов')

# %%
data_contract['ClientLeft'].value_counts()
# Out:
# 0    5942
# 1    1101
# Name: ClientLeft, dtype: int64

# %% [markdown]
# В целевом признаке наблюдается дисбаланс классов почти 6:1. Поскольку по условиям задачи нельзя использовать Upsampling/Downsampling, в подготовке данных для обучения воспользуемся методом `class_weight='balanced'`. Посмотрим соотношение в остальных признаках.

# %%
histogram(data_contract['Type'], 'Тип оплаты', 'Тип', 'Количество')

# %% [markdown]
# Клиенты оплачивают услуги ежемесячно, раз в год и раз в 2 года. Большинство - ежемесячно.

# %%
histogram(data_contract['PaymentMethod'], 'Метод оплаты', 'Метод', 'Количество', 10)

# %%
histogram(data_contract['MonthlyCharges'], 'Цена услуг за месяц', 'Цена', 'Количество', 50)

# %% [markdown]
# Интересно, что этот признак хранит много значений в широком диапазоне. Нужно посмотреть и статистическое распределение.

# %%
display(data_contract['MonthlyCharges'].describe())
plt.boxplot(data_contract['MonthlyCharges']);
plt.title('Диаграмма размаха по ценам');
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: MonthlyCharges, dtype: float64

# %% [markdown]
# ### Объединение датасетов, избавление от ненужных признаков
# В дальнейшем смотреть по одному столбцу не особо информативно, лучше объединить данные и изучить корреляцию. Поскольку мы уже преобразовали столбец customerID в индекс, можно использовать метод join.

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий тимлида:</b> Необходимо указать тип присоединения таблиц в явном виде, например:
#
#     how='left'
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Я была уверена, что это актуально только для merge, потому что join и так по умолчанию работает от left. Но дописала.</div>

# %%
data_all = data_contract.join(data_personal, how='left').join(data_internet, how='left').join(data_phone, how='left')
display(data_all.info())
data_all.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BeginDate         7043 non-null   datetime64[ns]
#  1   EndDate           7043 non-null   object
#  2   Type              7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7043 non-null   float64
#  7   ClientLeft        7043 non-null   int32
#  8   EndDateFilled     7043 non-null   datetime64[ns]
#  9   Duration          7043 non-null   int64
#  10  Gender            7043 non-null   object
#  11  SeniorCitizen     7043 non-null   int64
#  12  Partner           7043 non-null   object
#  13  Dependents        7043 non-null   object
#  14  InternetService   5517 non-null   object
#  15  OnlineSecurity    5517 non-null   object
# ...

# %% [markdown]
# Пропуски в услугах - InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies и MultipleLines, - скорее всего, означают, что указанные услуги не подключены. Их можно заменить на No, для единообразия с уже существующими данными.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> Согласен, можно заполнить пропуски таким образом 👍
#
# </div>

# %%
services = ['InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 
           'StreamingMovies', 'MultipleLines']
for column in services:
    data_all[column] = data_all[column].fillna('No')
    
main = ['Internet', 'Phone']
for column in main:
    data_all[column] = data_all[column].fillna(0)
    
data_all['Internet'] = data_all['Internet'].astype(int)
data_all['Phone'] = data_all['Phone'].astype(int)
data_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BeginDate         7043 non-null   datetime64[ns]
#  1   EndDate           7043 non-null   object
#  2   Type              7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7043 non-null   float64
#  7   ClientLeft        7043 non-null   int32
#  8   EndDateFilled     7043 non-null   datetime64[ns]
#  9   Duration          7043 non-null   int64
#  10  Gender            7043 non-null   object
#  11  SeniorCitizen     7043 non-null   int64
#  12  Partner           7043 non-null   object
#  13  Dependents        7043 non-null   object
#  14  InternetService   7043 non-null   object
#  15  OnlineSecurity    7043 non-null   object
# ...

# %% [markdown]
# Также заметно, что среди признаков есть как категориальные, так и численные. К категориальным впоследствии надо будет применить OneHotEncoding. Пока смотрим корреляцию численных признаков.

# %%
numeric = ['MonthlyCharges', 'TotalCharges', 'Duration']

# %%
data_all[numeric].corr()
# Out:
#                 MonthlyCharges  TotalCharges  Duration
# MonthlyCharges        1.000000      0.630448  0.220054
# TotalCharges          0.630448      1.000000  0.821731
# Duration              0.220054      0.821731  1.000000

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий тимлида:</b> На самом деле стоит еще проверить корреляцию после генерации дополнительных признаков, например длительности контракта
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента:</b> Так и сделала.</div>

# %% [markdown]
# MonthlyCharges и TotalCharges в некоторой степени коррелируют между собой, а ещё сильнее TotalCharges коррелирует с новым признаком Duration (что логично, суммы платежей складываются). Но корреляцию с категориальными переменными тут не посмотришь, поэтому воспользуемся библиотекой Phik. Но для начала нужно удалить некоторые вспомогательные столбцы.

# %%
for_drop = ['TotalCharges', 'BeginDate', 'EndDate', 'EndDateFilled']
data_clean = data_all.drop(for_drop, axis=1)
data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Type              7043 non-null   object
#  1   PaperlessBilling  7043 non-null   object
#  2   PaymentMethod     7043 non-null   object
#  3   MonthlyCharges    7043 non-null   float64
#  4   ClientLeft        7043 non-null   int32
#  5   Duration          7043 non-null   int64
#  6   Gender            7043 non-null   object
#  7   SeniorCitizen     7043 non-null   int64
#  8   Partner           7043 non-null   object
#  9   Dependents        7043 non-null   object
#  10  InternetService   7043 non-null   object
#  11  OnlineSecurity    7043 non-null   object
#  12  OnlineBackup      7043 non-null   object
#  13  DeviceProtection  7043 non-null   object
#  14  TechSupport       7043 non-null   object
#  15  StreamingTV       7043 non-null   object
# ...

# %%
phik_overview = data_clean.phik_matrix(interval_cols=numeric)

plot_correlation_matrix(phik_overview.values, 
                        x_labels=phik_overview.columns, 
                        y_labels=phik_overview.index, 
                        vmin=0, vmax=1, color_map="Greens", 
                        title=r"Коэффициент корреляции $\phi_K$", 
                        fontsize_factor=1.2, 
                        figsize=(20, 18))
plt.tight_layout()

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента:</b> зачёркиваю пункты, которые потеряли актуальность с правкой датасета</div>
#
# Здесь заметно, что между ~~многими~~ признаками наблюдается корреляция:
# * ~~MonthlyCharges, TotalCharges и BeginDate (общая оплата зависит от тарифа и того, сколько дней клиент пользуется услугами провайдера)~~
# * ~~EndDate и ClientLeft - целевой признак~~
# * MonthlyCharges и диапазон подключенных услуг (InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, MultipleLines) - стоимость тарифа зависит от того, что в него входит
# * ~~Type и BeginDate~~
# * Partner и Dependents (наличие супруга - наличие детей)
#
# После удаления лишних признаков и добавления двух дополнительных (Internet и Phone) картина корреляции где-то осталась прежней, а где-то добавились новые интересные коэффициенты:
# * довольно сильная корреляция признака Duration (длительность контракта в днях) и Type (тип периода оплаты - ежемесячный, раз в год, раз в 2 года)
# * слабая корреляция Duration и целевого признака ClientLeft
# * чуть более сильная - Duration и Partner
# * Internet сильно коррелирует с MonthlyCharges и InternetServices, что очевидно; возможно, что-то из признаков по услугам лучше будет удалить (или сами новые признаки)
# * у Phone сильная корреляция только с MonthlyCharges

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Здорово, что применила библиотеку phik для анализа корреляции смешанного набора признаков!
#
# ***
#
# Что касается корреляции категориальных признаков, то это пока что пища для размышлений, не стоит сразу по этому условию удалять признаки. Данная корреляция может быть нелинейная, и на линейные модели это не повлияет.
#
# </div>

# %%
significance_overview = data_clean.significance_matrix(interval_cols=numeric)
plot_correlation_matrix(significance_overview.fillna(0).values, 
                        x_labels=significance_overview.columns, 
                        y_labels=significance_overview.index, 
                        vmin=-3, vmax=10, title="Важность коэффициентов", 
                        usetex=False, fontsize_factor=1.2, figsize=(20, 18))
plt.tight_layout()

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента:</b> Тут я попробовала сменить масштаб шкалы для большей информативности.</div>
#
# Признак Gender - шумовой, у него нулевая корреляция с какими-либо параметрами и низкая значимость. Также интересно, что новый категориальный признак Internet показывает высокую значимость, а Phone - доволньо низкую.

# %% [markdown]
# Мы уже избавились от нескольких признаков, дающих мультиколлинеарность. Удалим также признак Gender, который не даёт полезной информации, т.к. ни с чем не коррелирует.

# %%
data_clean = data_clean.drop('Gender', axis=1)
data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Type              7043 non-null   object
#  1   PaperlessBilling  7043 non-null   object
#  2   PaymentMethod     7043 non-null   object
#  3   MonthlyCharges    7043 non-null   float64
#  4   ClientLeft        7043 non-null   int32
#  5   Duration          7043 non-null   int64
#  6   SeniorCitizen     7043 non-null   int64
#  7   Partner           7043 non-null   object
#  8   Dependents        7043 non-null   object
#  9   InternetService   7043 non-null   object
#  10  OnlineSecurity    7043 non-null   object
#  11  OnlineBackup      7043 non-null   object
#  12  DeviceProtection  7043 non-null   object
#  13  TechSupport       7043 non-null   object
#  14  StreamingTV       7043 non-null   object
#  15  StreamingMovies   7043 non-null   object
# ...

# %% [markdown]
# Мы получили относительно чистый датасет без паразитных признаков. Нужно проанализировать его детальнее, в частности, посмотреть на графиках, отличаются ли в чём-либо ушедшие и оставшиеся клиенты, а также не создают ли мультиколлинеарность какие-либо из оставшихся.
#
# ### Анализ категорий клиентов: ушедшие и действующие, использование услуг

# %%
plt.hist([data_clean[data_clean.ClientLeft == 0].MonthlyCharges, data_clean[data_clean.ClientLeft == 1].MonthlyCharges], 
         label=['Активные', 'Ушедшие'], density=True);
plt.legend();
plt.title('Тариф (ежемесячный платёж)');
plt.show();

# %% [markdown]
# Заметна закономерность: уходили в большей степени с дорогих тарифов.

# %%
plt.hist([data_clean[data_clean.Internet == 1].Internet, data_clean[data_clean.Phone == 1].Phone], 
         label=['Интернет', 'Телефон']);
plt.legend();
plt.title('Пользователи интернета и мобильной связи');
plt.show();

# %% [markdown]
# Несколько больше клиентов пользуются телефоном, но эти категории практически равны.
#
# Ранее мы заметили, что больше всего клиентов пользуются наиболее дешёвым тарифом, но это пользователи интернета или телефонной связи? Теперь мы можем это узнать.

# %%
low_charges = data_clean[data_clean.MonthlyCharges < 30]
low_charges.sample(5)
# Out:
#                       Type PaperlessBilling              PaymentMethod  \
# customerID
# 0795-XCCTE        Two year               No  Bank transfer (automatic)
# 3247-MHJKM  Month-to-month               No               Mailed check
# 2848-YXSMW        Two year               No    Credit card (automatic)
# 3115-CZMZD        Two year               No               Mailed check
# 1051-GEJLJ  Month-to-month               No               Mailed check
#
#             MonthlyCharges  ClientLeft  Duration  SeniorCitizen Partner  \
# customerID
# 0795-XCCTE           25.40           0      2191              1      No
# 3247-MHJKM           20.20           0        31              0      No
# 2848-YXSMW           19.40           1      1581              0     Yes
# 3115-CZMZD           20.25           0         0              0      No
# 1051-GEJLJ           19.50           0        62              0      No
#
#            Dependents InternetService OnlineSecurity OnlineBackup  \
# ...

# %%
plt.hist([low_charges[low_charges.Internet == 1].Internet, low_charges[low_charges.Phone == 1].Phone], 
         label=['Интернет', 'Телефон']);
plt.legend();
plt.title('Пользователи Интернета и телефона с наиболее дешёвым тарифом');
plt.show();

# %% [markdown]
# Перевес в сторону телефонной связи разительный. Смотрим также остальные категории услуг и информацию о пользователях (здесь я не прописываю заголовки, чтобы было меньше кода).

# %%
cols = ['InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 
        'StreamingMovies', 'MultipleLines', 'SeniorCitizen', 'Partner', 'Dependents']

for col in cols:
    plt.hist(data_clean[col]);
    plt.title(col);
    plt.show();

# %% [markdown]
# Здесь мы видим следующее:
# * большинство пользуется оптоволокном, несколько меньше - DSL
# * мало кто пользуется дополнительными услугами типа защиты, бэкапа, техподдержки и прочего
# * стриминговые сервисы и возможность поддерживать разговор по нескольким линиям тоже пользуются несколько меньшей популярностью, чем их отсутствие
# * возрастные пользователи в сильном меньшинстве
# * одинокие и семейные люди составляют почти равные доли, с небольшим перевесом в сторону одиноких; людей с иждивенцами несколько меньше
#
# Посмотрим корреляцию ещё раз.

# %%
phik_overview = data_clean.phik_matrix(interval_cols=numeric)

plot_correlation_matrix(phik_overview.values, 
                        x_labels=phik_overview.columns, 
                        y_labels=phik_overview.index, 
                        vmin=0, vmax=1, color_map="Greens", 
                        title=r"Коэффициент корреляции $\phi_K$", 
                        fontsize_factor=1.2, 
                        figsize=(20, 18))
plt.tight_layout()

# %% [markdown]
# Ради эксперимента датасет `data_clean` оставим неизменным, но создадим второй - `data_cleaner`, из которого уберём также столбцы с доп.услугами (оставим только общие категории Internet/Phone). Протестируем оба.

# %%
for_drop = ['InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 
            'StreamingTV', 'StreamingMovies', 'MultipleLines']

data_cleaner = data_clean.drop(for_drop, axis=1)
data_cleaner.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Type              7043 non-null   object
#  1   PaperlessBilling  7043 non-null   object
#  2   PaymentMethod     7043 non-null   object
#  3   MonthlyCharges    7043 non-null   float64
#  4   ClientLeft        7043 non-null   int32
#  5   Duration          7043 non-null   int64
#  6   SeniorCitizen     7043 non-null   int64
#  7   Partner           7043 non-null   object
#  8   Dependents        7043 non-null   object
#  9   Internet          7043 non-null   int32
#  10  Phone             7043 non-null   int32
# dtypes: float64(1), int32(3), int64(2), object(5)
# memory usage: 835.8+ KB

# %% [markdown]
# ## Создание выборок, обучение моделей
# ### Разбиение на выборки, ОНЕ
# Создаём списки численных и категориальных признаков.

# %%
numeric = ['MonthlyCharges', 'Duration']
categorical = ['Type', 'PaperlessBilling', 'PaymentMethod', 'SeniorCitizen', 'Partner', 'Dependents', 'Internet', 
               'Phone', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 
               'StreamingTV', 'StreamingMovies', 'MultipleLines']
categorical1 = ['Type', 'PaperlessBilling', 'PaymentMethod', 'SeniorCitizen', 'Partner', 'Dependents', 'Internet', 
               'Phone']

# %%
# назначение типа category для LGBM/CatBoost
for col in categorical:
    data_clean[col] = data_clean[col].astype('category')
    
for col in categorical1:
    data_cleaner[col] = data_cleaner[col].astype('category')

# %% [markdown]
# Выделяем обучающие и целевой признаки.

# %%
target = data_clean['ClientLeft']

features = data_clean.drop('ClientLeft', axis=1)
features1 = data_cleaner.drop('ClientLeft', axis=1)

# %% [markdown]
# Разделяем оба датасета на обучающую и тестовую выборки, после разбиения категориальные признаки перекодируем по OneHotEncoding.

# %%
# выборки из основного датасета
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=TEST_SIZE, random_state=RANDOM_STATE)

# выборки из более чистого датасета - посмотреть, что будет лучше
X1_train, X1_test, y1_train, y1_test = train_test_split(features1, target, test_size=TEST_SIZE, random_state=RANDOM_STATE)

X_train_ohe = X_train.copy() # отдельные выборки для ОНЕ-кодирования
X_test_ohe = X_test.copy()

X1_train_ohe = X1_train.copy()
X1_test_ohe = X1_test.copy()

# %% [markdown]
# Выделяем категориальные и численные признаки, категориальные кодируем в ОНЕ, а численные масштабируем. Поскольку у категориальных признаков довольно мало "категорий", должно хватить обычного OneHotEncoder, без необходимости OrdinalEncoder.

# %%
encoder_ohe = OneHotEncoder(drop='first', handle_unknown='ignore', sparse=False)

#обучаем энкодер на заданных категориальных признаках тренировочной выборки
encoder_ohe.fit(X_train_ohe[categorical])

#добавляем закодированные признаки в X_train_ohe
#encoder_ohe.get_feature_names_out() позволяет получить названия колонок
X_train_ohe[
    encoder_ohe.get_feature_names_out()
] = encoder_ohe.transform(X_train_ohe[categorical])

#удаляем незакодированные категориальные признаки (изначальные колонки)
X_train_ohe = X_train_ohe.drop(categorical, axis=1)

#создаём скейлер
scaler = StandardScaler()

#обучаем его на численных признаках тренировочной выборки, трансформируем её же
X_train_ohe[numeric] = scaler.fit_transform(X_train_ohe[numeric])

#смотрим на результат
X_train_ohe.head()
# Out:
#             MonthlyCharges  Duration  Type_One year  Type_Two year  \
# customerID
# 2082-CEFLT       -0.633974 -1.101961            0.0            0.0
# 5027-XWQHA       -0.662295 -0.919811            0.0            0.0
# 6941-KXRRV       -0.189172  0.835053            1.0            0.0
# 4716-MRVEN       -1.486927 -0.020906            1.0            0.0
# 8645-KWHJO       -0.320780 -0.696195            0.0            0.0
#
#             PaperlessBilling_Yes  PaymentMethod_Credit card (automatic)  \
# customerID
# 2082-CEFLT                   1.0                                    0.0
# 5027-XWQHA                   0.0                                    0.0
# 6941-KXRRV                   1.0                                    0.0
# 4716-MRVEN                   0.0                                    0.0
# 8645-KWHJO                   1.0                                    0.0
#
#             PaymentMethod_Electronic check  PaymentMethod_Mailed check  \
# customerID
# ...

# %%
# трансформируем тестовую выборку уже без обучения
X_test_ohe[
    encoder_ohe.get_feature_names_out()
] = encoder_ohe.transform(X_test_ohe[categorical])
X_test_ohe = X_test_ohe.drop(categorical, axis=1)
X_test_ohe[numeric] = scaler.transform(X_test_ohe[numeric])

X_test_ohe.head()
# Out:
#             MonthlyCharges  Duration  Type_One year  Type_Two year  \
# customerID
# 9554-DFKIC       -0.339106  0.025002            0.0            0.0
# 4282-ACRXS       -1.325333  0.384860            0.0            0.0
# 8792-AOROI        0.029064 -0.965719            0.0            1.0
# 4403-BWPAY       -1.326999 -0.832438            1.0            0.0
# 2898-MRKPI        1.213536  1.738400            1.0            0.0
#
#             PaperlessBilling_Yes  PaymentMethod_Credit card (automatic)  \
# customerID
# 9554-DFKIC                   1.0                                    0.0
# 4282-ACRXS                   1.0                                    0.0
# 8792-AOROI                   0.0                                    0.0
# 4403-BWPAY                   1.0                                    1.0
# 2898-MRKPI                   1.0                                    1.0
#
#             PaymentMethod_Electronic check  PaymentMethod_Mailed check  \
# customerID
# ...

# %% [markdown]
# ### Создание и обучение моделей
# Создадим модели, с помощью кросс-валидации подберём лучшую. Будем пробовать логистическую регрессию, случайный лес, CatBoost и LightGBM.

# %%
model_logistic = LogisticRegression(random_state=RANDOM_STATE, class_weight='balanced')
model_forest = RandomForestClassifier(random_state=RANDOM_STATE, class_weight='balanced')

# CatBoost и LightGBM будем учить на видеокарте
model_lgbm = LGBMClassifier(random_state=RANDOM_STATE, class_weight='balanced', objective='binary',
                            metric='binary_logloss', device='gpu', verbose=-1, gpu_use_dp=False, max_bin=63)
model_cat = CatBoostClassifier(cat_features=categorical, random_state=RANDOM_STATE, auto_class_weights='Balanced',
                              task_type="GPU", devices='0:1', gpu_ram_part=0.9, verbose=0)

# %% [markdown]
# Подбираем гиперпараметры с помощью GridSearchCV.
#
# Логистическая регрессия:

# %%
param_grid_logistic = {
    'solver': ['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga']
}

gs_logistic = GridSearchCV(
    model_logistic, 
    param_grid=param_grid_logistic, 
    scoring='roc_auc', 
    n_jobs=-1
)

gs_logistic.fit(X_train_ohe, y_train)

print(f'best_score: {gs_logistic.best_score_}')

print(f'best_params: {gs_logistic.best_params_}')

# %% [markdown]
# Случайный лес:

# %%
param_grid_rf = {
    'n_estimators': range(50, 301, 50),
    'max_depth': range(2, 20),
    'min_samples_split': (2, 3, 4, 5, 6),
    'min_samples_leaf': (1, 2, 3, 4, 5)
}

gs_rf = RandomizedSearchCV(
    model_forest,
    param_distributions=param_grid_rf,
    scoring='roc_auc',
    n_jobs=-1,
    random_state=RANDOM_STATE
)

gs_rf.fit(X_train_ohe, y_train)

gs_rf_best_score = gs_rf.best_score_
gs_rf_best_params = gs_rf.best_params_
print(f'best_score: {gs_rf_best_score}')
print(f'best_params: {gs_rf_best_params}')

# %% [markdown]
# CatBoost:

# %%
cat_parameters = {'depth': [3, 5, 7, 9, 11],
            'learning_rate': [0.5, 0.1, 0.05, 0.01],
            'iterations': [50, 100, 150, 200, 250]
}

grid_cat = GridSearchCV(model_cat, param_grid=cat_parameters, cv=2, n_jobs=None, scoring='roc_auc')
grid_cat.fit(X_train, y_train)
cat_best_score = grid_cat.best_score_
cat_best_params = grid_cat.best_params_
print("The best score across ALL searched params:", cat_best_score)
print("The best parameters across ALL searched params:", cat_best_params)

# %%
lgbm_parameters = {
    'max_depth': [3, 5, 7, 9, 11], 
    'learning_rate': [0.5, 0.1, 0.05, 0.01],
    'num_leaves': [15, 31, 63],
    'n_estimators': [50, 100, 150, 200, 250]
}

grid_lgbm = GridSearchCV(
    estimator=model_lgbm,
    param_grid=lgbm_parameters,
    cv=5,
    n_jobs=None
)
grid_lgbm.fit(X_train, y_train)
lgbm_best_score = grid_lgbm.best_score_
lgbm_best_params = grid_lgbm.best_params_
print("The best score across ALL searched params:", lgbm_best_score)
print("The best parameters across ALL searched params:", lgbm_best_params)

# %% [markdown]
# Лучшей моделью на кросс-валидации оказалась CatBoost, её и будем проверять на тестовой выборке.

# %% [markdown]
# ## Тестирование финальной модели, выводы
# ### Проверка модели на тестовой выборке
# Модель, которую мы в предыдущем разделе отобрали с помощью кросс-валидации, проверим на тестовой выборке. Это модель CatBoost. Также попробуем сравнить результат обучения по разным датасетам.

# %%
params = {'depth': 3,
          'iterations': 250,
          'learning_rate': 0.5,
         'cat_features': categorical,
          'random_state': RANDOM_STATE,
          'auto_class_weights': 'Balanced',
           'task_type': 'GPU',
          'devices':'0:1',
          'gpu_ram_part': 0.9,
          'verbose': 0
         }
final_model = CatBoostClassifier(**params)

final_model.fit(X_train, y_train)

# %%
predictions = final_model.predict_proba(X_test)[:, 1]
roc_auc_score(y_test, predictions)
# Out:
# 0.91892821192581

# %%
params1 = {'depth': 3,
          'iterations': 250,
          'learning_rate': 0.5,
         'cat_features': categorical1,
          'random_state': RANDOM_STATE,
          'auto_class_weights': 'Balanced',
           'task_type': 'GPU',
          'devices':'0:1',
          'gpu_ram_part': 0.9,
          'verbose': 0
         }
final_model1 = CatBoostClassifier(**params1)
final_model1.fit(X1_train, y1_train)
predictions1 = final_model1.predict_proba(X1_test)[:, 1]
roc_auc_score(y1_test, predictions1)
# Out:
# 0.9286317609655461

# %%
y_test
# Out:
# customerID
# 9554-DFKIC    0
# 4282-ACRXS    0
# 8792-AOROI    0
# 4403-BWPAY    1
# 2898-MRKPI    0
#              ..
# 8098-LLAZX    0
# 3030-YZADT    0
# 2696-NARTR    0
# 8746-BFOAJ    0
# 0928-XUTSN    0
# Name: ClientLeft, Length: 1761, dtype: int32

# %% [markdown]
# Как дополнительную метрику смотрим Accuracy:

# %%
predictions_acc = final_model.predict(X_test)
predictions_acc1 = final_model1.predict(X1_test)

acc = accuracy_score(y_test, predictions_acc)
acc1 = accuracy_score(y1_test, predictions_acc1)
print('Accuracy на первом датасете:', acc)
print('Accuracy на втором датасете:', acc1)
# Out:
# Accuracy на первом датасете: 0.8915388983532084
# Accuracy на втором датасете: 0.8915388983532084

# %% [markdown]
# Независимо от того, очищали ли мы датасет от дополнительных услуг, Accuracy идентична.

# %% [markdown]
# ### ROC-кривая

# %%
fpr, tpr, threshold = roc_curve(y_test, predictions)
fpr1, tpr1, threshold1 = roc_curve(y1_test, predictions1)
roc_auc = auc(fpr, tpr)
roc_auc1 = auc(fpr1, tpr1)
# строим график
plt.plot(fpr, tpr, color='darkorange',
         label='ROC кривая (area = %0.2f)' % roc_auc)
plt.plot(fpr1, tpr1, color='red',
         label='ROC кривая на очищенном датасете (area = %0.2f)' % roc_auc1)
plt.plot([0, 1], [0, 1], color='blue', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
plt.legend(loc="lower right")
plt.show()
print('ROC_AUC Метрика: ', roc_auc_score(y_test, predictions))
print('ROC_AUC Метрика 1: ', roc_auc_score(y1_test, predictions1))
# Out:
# ROC_AUC Метрика:  0.91892821192581
# ROC_AUC Метрика 1:  0.9286217945523585

# %% [markdown]
# ### Выводы
# В ходе работы было выполнено:
# * Предварительный анализ данных.
# * Предобработка (добавлены дополнительные признаки, все датасеты собраны в один, заполнены образовавшиеся пропуски).
# * Исследовательский анализ данных, в котором были рассмотрены особенности полученного датасета и проанализированы признаки на мультиколлинеарность с использованием функционала библиотеки Phik.
# * Подготовка к обучению: созданы два датасета (полный и с удалёнными признаками доп.услуг, вместо этого оставлены только категории Телефон/Интернет), кодирование признаков методом прямого кодирования OHE, маштабирование численных признаков.
# * Обучение моделей: были обучены модели LogisticRegression, RandomForestClassifier, CatBosstClassifier и LightGBM с помощью кросс-валидации; борьба с дисбалансом классов произведена методом `class_weight='balanced'`.
#
# В результате обучения лучше всего себя показала модель CatBoostClassifier на "экстраочищенном" датасете, на котором была достигнута метрика ROC_AUC = 0.93. Она же на оригинальном составляет ROC_AUC = 0.92.

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий тимлида:</b> В целом по плану работ все хорошо, но есть несколько замечаний:
#
# 1. План работ лучше оформить в одной ячейке, т.к. сейчас отдельные пункты плана по сути являются заголовками.
#
# 2. Необходимо будет дополнить исследовательский анализ данных:
#
# - анализ выше является лишь предварительным, поэтому в основном проекте обязательно должен быть подробный анализ и выводы. Например, распределение ежемесячных платежей для клиентов которые ушли и остались явно будет отличаться. Таким образом можно построить графики практически по всем признакам.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Оставила план в самом начале тетрадки. Исследовательский анализ тоже доработан.</div>

# %% [markdown]
# ## Уточняющие вопросы
# 1. Понадобится ли нам в обучении длительность использования (которую можно посчитать, вычтя `BeginDate` из `EndDate`)? В теории, это может оказаться полезно - найти зависимость между тем, сколько времени клиент пользуется услугами провайдера, и его уходом. Если да, как её рассчитать для ещё действующих клиентов (у которых в `EndDate` стоит No)? Вычитать BeginDate из даты формирования датасета, или это будет неверным?
# 2. Признак Gender выдаёт близкую к нулю корреляцию со всеми остальными - это поможет или помешает? Я знаю, что сильная корреляция мешает, а про её полное отсутствие пока плохо понимаю.
# 3. Очень много коэффициентов определяются как статистически значимые в significance matrix - в их числе есть и "мультиколлинеарные" признаки. Нужно ли избавляться от тех, чья значимость определена как низкая?
#
# ## Цель проекта
# Цель - научиться определять по косвенным признакам, уйдёт клиент от провайдера или нет, и если некий клиент собирается уйти - предложить ему "плюшки", которые смогут убедить его остаться (промокод, специальные условия тарифа и т.д.) Метрикой здесь будет служить ROC-кривая, показывающая ошибки:
# * пользователю предложили спец.условия, но он не собирался уходить (false positive)
# * пользователю ничего не предложили и он ушёл (false negative)

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Ольга, по твоим вопросам:
#
# 1. Длительность контракта это очень полезный признак, стоит его рассчитать. Если клиент действующий, то мы берем дату выгрузки датасета: 01 февраля 2020 года. После этого можно удалить признаки BeginDate из EndDate.
#
# 2. Если корреляция слабая, то признак является шумовым, в принципе можно удалить, здесь на твое усмотрение.
#
# 3. Про мультиколлинеарность написал выше, у категориальных признаков корреляция может быть нелинейная, не нужно удалять такие признаки.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> План работ принят, можно приступать к основному проекту.
#
# Сохрани пожалуйста наши с тобой комментарии, а проект продолжай в этом же файле. Успехов!
# </div>
